# %% [markdown]
# Importing Libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt # for visualization
import pandas as pd 
import seaborn as sns # for Data utilization purpose

# %% [markdown]
# Data Preprocessing

# %% [markdown]
# Training Image Processing

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    'train',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32, # If I want to faster the process, change to 64 or  128
    image_size=(128, 128),
    shuffle=True, # shuffle , helps to reduce the biasness/ randomly takes to learn better
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 18345 files belonging to 10 classes.

# %% [markdown]
# #### Validation Image Preprocessing

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 4585 files belonging to 10 classes.

# %% [markdown]
# #### To avoid Overshooting loss Function

# %% [markdown]
# 1. Choose small learning rate default 0.001 here we have taken 0.0001
# 2. There may be chance of underfitting so increase number of neuron
# 3. Add more Convolutional Layer to extract more feature from images there may be possibilty that model unable to capture relevant feature or model is confusing due to lack of feature so feed with more featur

# %% [markdown]
# #### Building Model

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# #### Building Convolution Layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,padding='same',activation='relu',input_shape=[128,128,3]))
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=64,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=64,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=128,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=128,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=256,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=256,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=512,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=512,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Dropout(0.25))  # dropping 25% of layers

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=1500,activation='relu'))

# %%
cnn.add(tf.keras.layers.Dropout(0.4)) #To avoid overfitting dropping 40% of neurons

# %%
#Output Layer
cnn.add(tf.keras.layers.Dense(units=10,activation='softmax')) 
# I need result in probability form, we are using softmax as activation function

# %% [markdown]
# ####  Compiling and Training Phase

# %%
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
cnn.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)                   │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 126, 126, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 63, 63, 64)          │          18,496 │
# ...

# %% [markdown]
# ### Model Training

# %%
training_history = cnn.fit(x=training_set,validation_data=validation_set,epochs=10)
# Out:
# Epoch 1/10
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 981s 2s/step - accuracy: 0.4061 - loss: 1.6513 - val_accuracy: 0.7588 - val_loss: 0.7108
# Epoch 2/10
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 971s 2s/step - accuracy: 0.7990 - loss: 0.5859 - val_accuracy: 0.8576 - val_loss: 0.4070
# Epoch 3/10
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 1114s 2s/step - accuracy: 0.8614 - loss: 0.3941 - val_accuracy: 0.8960 - val_loss: 0.3098
# Epoch 4/10
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 1331s 2s/step - accuracy: 0.8996 - loss: 0.2851 - val_accuracy: 0.9106 - val_loss: 0.2609
# Epoch 5/10
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 1121s 2s/step - accuracy: 0.9270 - loss: 0.2097 - val_accuracy: 0.9361 - val_loss: 0.1920
# Epoch 6/10
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 1099s 2s/step - accuracy: 0.9365 - loss: 0.1839 - val_accuracy: 0.9326 - val_loss: 0.2184
# Epoch 7/10
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 1077s 2s/step - accuracy: 0.9451 - loss: 0.1589 - val_accuracy: 0.9112 - val_loss: 0.2853
# Epoch 8/10
# ...

# %% [markdown]
# #### Evaluating Model

# %%
#Training set Accuracy
train_loss, train_acc = cnn.evaluate(training_set)
print('Training accuracy:', train_acc)
# Out:
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 441s 767ms/step - accuracy: 0.9559 - loss: 0.1268
# Training accuracy: 0.960098147392273

# %%
#Validation set Accuracy
val_loss, val_acc = cnn.evaluate(validation_set)
print('Validation accuracy:', val_acc)
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 91s 625ms/step - accuracy: 0.9137 - loss: 0.3000
# Validation accuracy: 0.9153762459754944

# %% [markdown]
# #### Saving Model

# %%
cnn.save('trained_plant_disease_model.keras') # save the file so no need to train everytime

# %%
training_history.history #Return Dictionary of history
# Out:
# {'accuracy': [0.5883346796035767,
#   0.8215862512588501,
#   0.8745707273483276,
#   0.9053148031234741,
#   0.9318070411682129,
#   0.9417824745178223,
#   0.9504497051239014,
#   0.9659307599067688,
#   0.9661487936973572,
#   0.9704551696777344],
#  'loss': [1.154984951019287,
#   0.5168254375457764,
#   0.36237651109695435,
#   0.27246224880218506,
#   0.19697453081607819,
#   0.17184118926525116,
#   0.14157071709632874,
#   0.10107337683439255,
#   0.0980319231748581,
#   0.08632504194974899],
#  'val_accuracy': [0.7587786316871643,
#   0.8575790524482727,
#   0.8959650993347168,
#   0.9105779528617859,
#   0.9360959529876709,
#   0.9326063394546509,
#   0.9112322926521301,
#   0.9443838596343994,
#   0.9376226663589478,
#   0.9153762459754944],
#  'val_loss': [0.7108405232429504,
#   0.4070203900337219,
#   0.30977264046669006,
#   0.26091480255126953,
#   0.19200393557548523,
#   0.21836265921592712,
#   0.28525644540786743,
#   0.1924637109041214,
#   0.20119543373584747,
# ...

# %%
#Recording History in json
import json
with open('training_hist.json','w') as f:
  json.dump(training_history.history,f)

# %%
print(training_history.history.keys())
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %% [markdown]
# #### Accuracy Validation

# %%
epochs = [i for i in range(1,11)]
plt.plot(epochs,training_history.history['accuracy'],color='red',label='Training Accuracy')
plt.plot(epochs,training_history.history['val_accuracy'],color='blue',label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.ylabel('Accuracy Result')
plt.title('Visualization of Accuracy Result')
plt.legend()
plt.show()

# %% [markdown]
# #### Some other matrics for model evaluation

# %%
class_name = validation_set.class_names

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=1,
    image_size=(128, 128),
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 4585 files belonging to 10 classes.

# %%
y_pred = cnn.predict(test_set)
predicted_categories = tf.argmax(y_pred, axis=1)
# Out:
# 4585/4585 ━━━━━━━━━━━━━━━━━━━━ 268s 58ms/step

# %%
true_categories = tf.concat([y for x, y in test_set], axis=0)
Y_true = tf.argmax(true_categories, axis=1) #vertically take the max value of probability

# %%
Y_true
# Out:
# <tf.Tensor: shape=(4585,), dtype=int64, numpy=array([0, 0, 0, ..., 9, 9, 9], dtype=int64)>

# %%
predicted_categories
# Out:
# <tf.Tensor: shape=(4585,), dtype=int64, numpy=array([0, 0, 0, ..., 9, 9, 9], dtype=int64)>

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm = confusion_matrix(Y_true,predicted_categories)

# %%
# Precision Recall Fscore
print(classification_report(Y_true,predicted_categories,target_names=class_name))
# Out:
#                                                precision    recall  f1-score   support
#
#                       Tomato___Bacterial_spot       0.96      0.93      0.95       425
#                         Tomato___Early_blight       0.93      0.77      0.84       480
#                          Tomato___Late_blight       0.81      0.96      0.88       463
#                            Tomato___Leaf_Mold       0.96      0.91      0.94       470
#                   Tomato___Septoria_leaf_spot       0.96      0.75      0.84       436
# Tomato___Spider_mites Two-spotted_spider_mite       0.94      0.93      0.93       435
#                          Tomato___Target_Spot       0.84      0.94      0.89       457
#        Tomato___Tomato_Yellow_Leaf_Curl_Virus       0.90      1.00      0.95       490
#                  Tomato___Tomato_mosaic_virus       0.92      0.98      0.95       448
#                              Tomato___healthy       0.97      0.98      0.97       481
#
# ...

# %% [markdown]
# #### Confusion Matrix Visualization

# %%
plt.figure(figsize=(40, 40))
sns.heatmap(cm,annot=True,annot_kws={"size": 10})

plt.xlabel('Predicted Class',fontsize = 20)
plt.ylabel('Actual Class',fontsize = 20)
plt.title('Plant Disease Prediction Confusion Matrix',fontsize = 25)
plt.show()
